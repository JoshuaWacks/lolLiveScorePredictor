# %%
import pandas as pd

# %%
df = pd.read_csv('./data/CHAMP_SELECT_2024.csv')

# %%
df[df.isnull().any(axis=1)]
# Out:
#      gol_game_num blue_ban_0    blue_ban_1 blue_ban_2    blue_ban_3  \
# 137         56709   Xin Zhao  Twisted Fate        NaN        Aatrox
# 149         56413      Senna         Akali   Nautilus            Vi
# 182         55964      Senna         Viego    Smolder      Tristana
# 227         55144      Karma          Ashe      Varus          Hwei
# 253         55113      Milio         Karma   Tristana       Taliyah
# 294         54986         Vi        Darius       Ashe      Tristana
# 619         57615    Orianna       Kalista   Renekton       Lee Sin
# 696         54037       Udyr            Vi      Rakan      Tristana
# 836         57276     Rumble       Kalista       Ashe  Twisted Fate
#
#     blue_ban_4      blue_top blue_jungle      blue_mid blue_bot  ...  \
# 137         Vi           Jax       Brand         Karma    Varus  ...
# 149      Viego        Aatrox       Poppy          Hwei     Zeri  ...
# 182        NaN        Aatrox    Xin Zhao         Karma    Xayah  ...
# ...
